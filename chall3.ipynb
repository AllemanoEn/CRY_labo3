# %%
c31 = ...
c32 = ...
e31 = 65537
e32 = 10633823966279326983230456482242756773
n3 = ...

# %%
print(gcd(e31,e32))

F = Integers(n3)

x = xgcd(e31,e32)[1]
y = xgcd(e31,e32)[2]

c31 = F(c31)
c32 = F(c32)

m = pow(c31,x)*pow(c32,y)

# Compute the right length to display
l = len(bin(m)) - 2
l = (l//8)+1

m = int(m)

print(int.to_bytes(m, l, byteorder='little'))
# Out:
# 1
# b'You shall not pass. At least not without the password chastisement'
